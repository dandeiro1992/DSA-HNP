# %%
B=matrix([[2,2],[4,1]])
print(B.rows())
# Out:
# [(2, 2), (4, 1)]

# %%
points=[]
for i in range (-2,2,1):
    for j in range (-2,2,1):
        points.append(vector([i,j]))
print(points)
b=points
points[:] = [x *B for x in points]
print(points)
# Out:
# [(-2, -2), (-2, -1), (-2, 0), (-2, 1), (-1, -2), (-1, -1), (-1, 0), (-1, 1), (0, -2), (0, -1), (0, 0), (0, 1), (1, -2), (1, -1), (1, 0), (1, 1)]
# [(-12, -6), (-8, -5), (-4, -4), (0, -3), (-10, -4), (-6, -3), (-2, -2), (2, -1), (-8, -2), (-4, -1), (0, 0), (4, 1), (-6, 0), (-2, 1), (2, 2), (6, 3)]

# %%
m=(2,3)
list_plot(b)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
dimension=10
lattice_points=[]
for i in range (-dimension,dimension,1):
    for j in range (-dimension,dimension,1):
        m=vector([i,j])*B^(-1)
        if m[0] in ZZ and m[1] in ZZ:
            lattice_points.append(vector([i,j]))
print(lattice_points)
# Out:
# [(-10, -10), (-10, -7), (-10, -4), (-10, -1), (-10, 2), (-10, 5), (-10, 8), (-8, -8), (-8, -5), (-8, -2), (-8, 1), (-8, 4), (-8, 7), (-6, -9), (-6, -6), (-6, -3), (-6, 0), (-6, 3), (-6, 6), (-6, 9), (-4, -10), (-4, -7), (-4, -4), (-4, -1), (-4, 2), (-4, 5), (-4, 8), (-2, -8), (-2, -5), (-2, -2), (-2, 1), (-2, 4), (-2, 7), (0, -9), (0, -6), (0, -3), (0, 0), (0, 3), (0, 6), (0, 9), (2, -10), (2, -7), (2, -4), (2, -1), (2, 2), (2, 5), (2, 8), (4, -8), (4, -5), (4, -2), (4, 1), (4, 4), (4, 7), (6, -9), (6, -6), (6, -3), (6, 0), (6, 3), (6, 6), (6, 9), (8, -10), (8, -7), (8, -4), (8, -1), (8, 2), (8, 5), (8, 8)]

# %%
list_plot(lattice_points)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
C=matrix([[3010,3004],[1504,1501]])
print(C)
# Out:
# [3010 3004]
# [1504 1501]

# %%
print(C.LLL())
# Out:
# [ 2 -1]
# [ 2  2]

# %%
D=matrix([[3010,3004,0],[1504,1501,0],[6,2,1]])
print(D.LLL())
# Out:
# [ 0 -1  1]
# [ 2 -1  0]
# [ 0  1  2]

# %%
n=vector([3013,3003])*B^(-1)
if n[0] in ZZ and n[1] in ZZ:
    lattice_points.append(vector([i,j]))
print(n)
# Out:
# (8999/6, 10/3)

# %%
D=matrix([[3010,3004,0],[1504,1501,0],[3012,3004,1]])
print(D.LLL())
# Out:
# [ 0  1  1]
# [ 2 -1  0]
# [ 0  1 -2]
